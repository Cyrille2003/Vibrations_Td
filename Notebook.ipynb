# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot([3,4,5], [9,16,25], label="tocotc")

# %%
import pandas as pd


tableau = pd.DataFrame(columns=["x1", "x2", "x3"])
new_line = pd.DataFrame([{"x1":"texte1", "x2":"textDSDFGe2", "x3":"textdghsdhe3"}])
tableau = pd.concat([tableau, new_line], ignore_index=True)
print(tableau)
# Out:
#        x1           x2            x3
# 0  texte1  textDSDFGe2  textdghsdhe3

# %%
from Classe_systeme import System

system1 = System(50, 20, 10, 1000, 10, 0.1, 0.5)
print(system1.td_analytique())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 from Classe_systeme import System
#       3 system1 = System(50, 20, 10, 1000, 10, 0.1, 0.5)
# ----> 4 print(system1.td_analytique())
#
# File c:\Users\cyril\OneDrive\Bureau\Scolarité\Université Laval\1. Sessions\Hiver 2026\3.GMC-3000\Étude_Systeme_Amorti\Td\Vibrations_Td\Classe_systeme.py:109, in System.td_analytique(self)
#     106 eq1 = lambda t: integrale(self.c * (self.X*self.w*cos(self.w*t+self.phi))**2, t, t+self.tho_d, h=1e-5)
#     107 eq2 = lambda t: integrale(self.F * sin(self.w*t) * self.X*self.w*cos(self.w*t + self.phi), t, t+self.tho_d, h=1e-5)
# --> 109 return Newton_nD([self.temps], [eq1 - eq2])
#
# TypeError: unsupported operand type(s) for -: 'function' and 'function'
